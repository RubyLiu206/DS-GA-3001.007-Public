# %% [markdown]
# ## Introduction to Machine Learning
# ### Lab 10: Support Vector Machines
#
# _**Adapted from materials of Sundeep Ranjan**_

# %%
from IPython.display import Image

# %%
Image('one.PNG',height = 4000, width =600)

# %% [markdown]
# a. Find a linear classifier that separates the two classes.
# Your classifier should be of the form
#
# $$
#     \hat{y} = \begin{cases}
#         1 & \mbox{if } b + w_1 x_1 + w_2 x_2 > 0 \\
#         -1 & \mbox{if } b + w_1 x_1 + w_2 x_2 < 0
#     \end{cases}
# $$
#
# State the intercept $b$ and weights $w_1$ and $w_2$ for your classifier.
# Note there is no unique answer as there are multiple linear classifiers
# that could separate the classes.

# %%
### YOUR ANSWERS HERE

# %% [markdown]
# b. Find the maximum $\gamma$ such that
#
# $$
#     y_i(b+w_1x_{i1} + w_{i2}x_{i2}) \geq \gamma, \mbox{ for all } i,
# $$
#
# for the classifier in part (a)?

# %%
### YOUR ANSWERS HERE

# %% [markdown]
# c. Compute the margin of the classifier
#
# $$
# m = \frac{\gamma}{\|w\|}, \quad \|w\|= \sqrt{ w_1^2 + w_2^2 }.
# $$

# %%
### YOUR ANSWERS HERE

# %% [markdown]
# d. Which samples $i$ are on the margin for your classifier?

# %%
### YOUR ANSWERS HERE

# %%
Image('two.PNG',height = 4000, width =600)

# %% [markdown]
# a. Write a short python program to plot $J(t)$ vs. $t$ for
# 100 values of $t$ in the interval $t \in [0,5]$.

# %%
### YOUR ANSWERS HERE

# %% [markdown]
# b. Based on the plot, what is one value of $t$ that minimizes
# $J(t)$.

# %%
### YOUR ANSWERS HERE

# %% [markdown]
# c. For the value of $t$ in part (b), find the corresponding
# slack variables $\epsilon_i$.

# %%
### YOUR ANSWERS HERE

# %% [markdown]
# d. Which samples $i$ violate the margin ($\epsilon_i > 0$)
# and which samples $i$ are misclassified ($\epsilon_i > 1$)

# %%
### YOUR ANSWERS HERE

# %%
Image('three.PNG',height = 4000, width =600)

# %% [markdown]
# Recall that in linear classification, the $4 \times 4$
# image matrices $X$ and $W$
# can be represented as 16-dimensional vectors, $x = \mathrm{vec}(X)$
# and $w = \mathrm{vec}(W)$ by stacking the columns of the matrices
# vertically. What are $x$ and $w$ for the matrices above.
#
# a. What is the inner product $z = w^T x$.

# %%
### YOUR ANSWERS HERE

# %% [markdown]
# b. What is the inner product $z = w^T x_{\rm right}$ where
# $x_{\rm right}$ is
# the vector corresponding to the matrix $X$ right shifted by one pixel
# with the left column filled with zeros.

# %%
### YOUR ANSWERS HERE

# %% [markdown]
# c. What is the inner product $z = w^T x_{\rm left}$ where
# $x_{\rm left}$ is
# the vector corresponding to the matrix $X$ left shifted by one pixel
# with the right column filled with zeros.

# %%
### YOUR ANSWERS HERE

# %% [markdown]
# d. Write the python command called `convert` that can covert a $4 \times 4$ image matrix, `Xmat`
# to the 16-dimensional vector, `x`.

# %%
### BEGIN SOLUTION

### END SOLUTION

# %%
# TEST

Xmat = np.ones((4,4))
assert convert(Xmat).shape == (16,)

# %% [markdown]
# e. Write a Python command called `uncovert` to go from `x` to `Xmat`.

# %%
### BEGIN SOLUTION

### END SOLUTION

# %%
# TEST

x = np.arange(16)
assert unconvert(x).shape == (4,4)
